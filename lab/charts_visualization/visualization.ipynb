# %%
#import statements
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('stocknews/upload_DJIA_table.csv')
df.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2016-07-01  17924.240234  18002.380859  17916.910156  17949.369141
# 1  2016-06-30  17712.759766  17930.609375  17711.800781  17929.990234
# 2  2016-06-29  17456.019531  17704.509766  17456.019531  17694.679688
# 3  2016-06-28  17190.509766  17409.720703  17190.509766  17409.720703
# 4  2016-06-27  17355.210938  17355.210938  17063.080078  17140.240234
#
#       Volume     Adj Close
# 0   82160000  17949.369141
# 1  133030000  17929.990234
# 2  106380000  17694.679688
# 3  112190000  17409.720703
# 4  138740000  17140.240234

# %%
df.columns = ['date','opening','maximum','minimum','closing','volume','adj_close']
plt.scatter(df.date[ : 10],df.maximum[ : 10],marker='o')
plt.show()

# %%
df.tail().boxplot(by='date', column=['volume'])

# %%
df['maximum'].plot.kde()

# %%
sy = pd.read_csv('data/spotify.csv')
sy.columns = ['date','shape_of_you','despacito','something_just_like','humble','unforgettable']
sy.fillna({'despacito': sy.despacito.median(), 'something_just_like': sy.something_just_like.median(),'humble':sy.humble.median(), 'unforgettable':sy.unforgettable.median()},inplace=True)
sy.head()
# Out:
#          date  shape_of_you  despacito  something_just_like     humble  \
# 0  2017-01-06      12287078  6889959.0            3704051.0  3629817.5
# 1  2017-01-07      13190270  6889959.0            3704051.0  3629817.5
# 2  2017-01-08      13099919  6889959.0            3704051.0  3629817.5
# 3  2017-01-09      14506351  6889959.0            3704051.0  3629817.5
# 4  2017-01-10      14275628  6889959.0            3704051.0  3629817.5
#
#    unforgettable
# 0      4772899.0
# 1      4772899.0
# 2      4772899.0
# 3      4772899.0
# 4      4772899.0

# %%
sy['shape_of_you'].plot.kde()

# %%
sy.head(10).boxplot(by='date', column=['despacito'])

# %%
sns.set(style="whitegrid")
ax = sns.violinplot(x=df.head(10).date,y=df.head(10).volume)

# %%
sy.head(20).hist(column='shape_of_you')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5018d7ddd0>]],
#       dtype=object)
